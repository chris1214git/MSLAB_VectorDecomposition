# %%
from tqdm.auto import tqdm
import fasttext
import fasttext.util

# %%
fasttext.util.download_model('en', if_exists='ignore') 
ft = fasttext.load_model('cc.en.300.bin')

fasttext.util.reduce_model(ft, 50)
ft.get_dimension()

file_name = '../data/fasttext.en.50d.txt'
with open(file_name, 'w') as f:
    for word in tqdm(ft.words):
        word_emb = ft.get_word_vector(word)
        print("{}".format(word), end=' ', file=f)
        for i in range(len(word_emb)):
            print("{:.6f}".format(word_emb[i]), end=' ', file=f)
        print("",file=f)

# %%
fasttext.util.download_model('en', if_exists='ignore') 
ft = fasttext.load_model('cc.en.300.bin')

fasttext.util.reduce_model(ft, 100)
ft.get_dimension()

file_name = '../data/fasttext.en.100d.txt'
with open(file_name, 'w') as f:
    for word in tqdm(ft.words):
        word_emb = ft.get_word_vector(word)
        print("{}".format(word), end=' ', file=f)
        for i in range(len(word_emb)):
            print("{:.6f}".format(word_emb[i]), end=' ', file=f)
        print("",file=f)

# %%
fasttext.util.download_model('en', if_exists='ignore') 
ft = fasttext.load_model('cc.en.300.bin')

fasttext.util.reduce_model(ft, 200)
ft.get_dimension()

file_name = '../data/fasttext.en.200d.txt'
with open(file_name, 'w') as f:
    for word in tqdm(ft.words):
        word_emb = ft.get_word_vector(word)
        print("{}".format(word), end=' ', file=f)
        for i in range(len(word_emb)):
            print("{:.6f}".format(word_emb[i]), end=' ', file=f)
        print("",file=f)
# Out:
# ...
#  (0.54%) [>                                                  ]                                                  ]>                                                  ]>                                                  ]>                                                  ]>                                                  ]>                                                  ]                                                  ]>                                                  ]>                                                  ]>                                                  ]>                                                  ]>                                                  ]>                                                  ]>                                                  ]                                                  ]>                                                  ]>                                                  ]>                                                  ]>  
# ...

# %%
fasttext.util.download_model('en', if_exists='ignore') 
ft = fasttext.load_model('cc.en.300.bin')

file_name = '../data/fasttext.en.300d.txt'
with open(file_name, 'w') as f:
    for word in tqdm(ft.words):
        word_emb = ft.get_word_vector(word)
        print("{}".format(word), end=' ', file=f)
        for i in range(len(word_emb)):
            print("{:.6f}".format(word_emb[i]), end=' ', file=f)
        print("",file=f)
# Out:
# ...
#   0%|          | 0/2000000 [00:00<?, ?it/s]
